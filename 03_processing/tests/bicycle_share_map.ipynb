# %% [markdown]
# Import libraries

# %%
import pandas as pd
import folium

# %% [markdown]
# Read the data

# %%
# read the data using pandas
df = pd.read_csv(r'C:\Users\matia\Desktop\report\step1\OSLO\2024_mai.csv')

# %% [markdown]
# Filter and manipulate the data
# - Extract all station names using start_station_name with corresponding latitude and longitude data
# - Store names and corresponding latitude and longitude data

# %%
# extract all the start_station_names and corresponding latitudes and longitudes
# use column "start_station_name" to extract the start station names
# use column "start_station_latitude" to extract the latitude of the start station
# use column "start_station_longitude" to extract the longitude of the start station
# use drop_duplicates() to remove duplicates

# store results in a new dataframe called map_data

# %% [markdown]
# Create the map using folium

# %%
# create map object

# %% [markdown]
# Create a marker for every single station using the longitude and latitude data
# - Each marker displayed with start_station_name in the legend

# %%
# add a marker for each station in the map object

# save the map object to an html file called "oslo__bysykkel_map.html"
